# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_df = pd.read_csv("./train.csv")

# %%
train_df.nunique()
# Out:
# image_id               200840
# grapheme_root             168
# vowel_diacritic            11
# consonant_diacritic         7
# grapheme                 1295
# dtype: int64

# %%
class_map = pd.read_csv("./class_map.csv")

# %%
class_map.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
train_df.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
sample_submission = pd.read_csv("./sample_submission.csv")

# %%
sample_submission
# Out:
#                          row_id  target
# 0    Test_0_consonant_diacritic       0
# 1          Test_0_grapheme_root       0
# 2        Test_0_vowel_diacritic       0
# 3    Test_1_consonant_diacritic       0
# 4          Test_1_grapheme_root       0
# 5        Test_1_vowel_diacritic       0
# 6    Test_2_consonant_diacritic       0
# 7          Test_2_grapheme_root       0
# 8        Test_2_vowel_diacritic       0
# 9    Test_3_consonant_diacritic       0
# 10         Test_3_grapheme_root       0
# 11       Test_3_vowel_diacritic       0
# 12   Test_4_consonant_diacritic       0
# 13         Test_4_grapheme_root       0
# 14       Test_4_vowel_diacritic       0
# 15   Test_5_consonant_diacritic       0
# 16         Test_5_grapheme_root       0
# 17       Test_5_vowel_diacritic       0
# 18   Test_6_consonant_diacritic       0
# 19         Test_6_grapheme_root       0
# 20       Test_6_vowel_diacritic       0
# 21   Test_7_consonant_diacritic       0
# 22         Test_7_grapheme_root       0
# 23       Test_7_vowel_diacritic       0
# 24   Test_8_consonant_diacritic       0
# 25         Test_8_grapheme_root       0
# 26       Test_8_vowel_diacritic       0
# 27   Test_9_consonant_diacritic       0
# 28         Test_9_grapheme_root       0
# 29       Test_9_vowel_diacritic       0
# 30  Test_10_consonant_diacritic       0
# 31        Test_10_grapheme_root       0
# 32      Test_10_vowel_diacritic       0
# 33  Test_11_consonant_diacritic       0
# 34        Test_11_grapheme_root       0
# 35      Test_11_vowel_diacritic       0
